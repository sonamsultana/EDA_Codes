# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=10
b=20
c=a+b
print(c)

# %%
bank_df=pd.read_csv(r'C:\Users\Admin\Downloads\bank.csv',sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
visadataset_df=pd.read_csv(r'C:\Users\Admin\Downloads\visadataset.csv')
visadataset_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **methods apply on visadataset**
# - shape
# - size
# - len
# - columns
# - head
# - tail
# - isnull
# - dtypes
# - info

# %%
visadataset_df.shape
# Out:
# (25480, 12)

# %%
visadataset_df.size
# Out:
# 305760

# %%
len(visadataset_df)
# Out:
# 25480

# %%
visadataset_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visadataset_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visadataset_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visadataset_df.tail(7)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25473                     N             2421         2007
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# ...

# %%
visadataset_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visadataset_df.isnull().sum() # column wise null value
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
data_types=visadataset_df.dtypes
data_types
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(data_types)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - Series type has without column names
# - we can directly apply math operations
# - Series is a kind of dictionary means key-value pair

# %%
visadataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# ### 24/04/25

# %%
keys=data_types.keys()
keys
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
values=data_types.values
values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
data_types_df=pd.DataFrame(zip(keys,values),columns=['Column_name','Data_type'])
data_types_df
# Out:
#               Column_name Data_type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
data_types_df.to_csv('data_types_df.csv',index=False)

# %% [markdown]
# **task-2**
# - separate catagorical and numerical columns

# %%
data_types_df[data_types_df['data_types']=='object']
data_types_df[data_types_df['data_types']!='object']

# %%
cat_list=[]
num_list=[]
for keys,values in zip(keys,values):
    if values=='object':
        cat_list.append(keys)
    else:
        num_list.append(keys)


print(cat_list)
print(num_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cat_list=[]
num_list=[]
for i,j in zip(keys,values):
    if j=='object':
        cat_list.append(i)
    else:
        num_list.append(i)


print(cat_list)
print(num_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 3
#       1 cat_list=[]
#       2 num_list=[]
# ----> 3 for i,j in zip(keys,values):
#       4     if j=='object':
#       5         cat_list.append(i)
#
# TypeError: 'numpy.dtypes.ObjectDType' object is not iterable

# %%
cate_list=[]
nume_list=[]
m=dict(data_types).items()
for i,j in m:
    if j==object:
        cate_list.append(i)
    else:
        nume_list.append(i)

print(cate_list)
print(nume_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
dict(data_types_df)
# Out:
# {'Column_name': 0                   case_id
#  1                 continent
#  2     education_of_employee
#  3        has_job_experience
#  4     requires_job_training
#  5           no_of_employees
#  6               yr_of_estab
#  7      region_of_employment
#  8           prevailing_wage
#  9              unit_of_wage
#  10       full_time_position
#  11              case_status
#  Name: Column_name, dtype: object,
#  'Data_type': 0      object
#  1      object
#  2      object
#  3      object
#  4      object
#  5       int64
#  6       int64
#  7      object
#  8     float64
#  9      object
#  10     object
#  11     object
#  Name: Data_type, dtype: object}

# %%
catagorical_list=[]
numerical_list=[]
for i in dict(data_types).items():
    if i[1]=="object":
        catagorical_list.append(i[0])
    else:
        numerical_list.append(i[0])

print(catagorical_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']

# %%
print(numerical_list)
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cate_list=[]
nume_list=[]
m=dict(data_types).items()
for i,j in m:
    if j=="object":
        cate_list.append(i)
    else:
        nume_list.append(i)

print(cate_list)
print(nume_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cat_list,num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
[key for key,value in dict(data_types).items() if value=='object']
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
[key for key,value in dict(data_types).items() if value!='object']
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cat=[i for i,j in zip(keys,values) if j=='object']
cat
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 cat=[i for i,j in zip(keys,values) if j=='object']
#       2 cat
#
# TypeError: 'numpy.dtypes.ObjectDType' object is not iterable

# %% [markdown]
# **select_dtypes**

# %%
visadataset_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visadataset_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **selection of data**
#
# - take
# - loc
# - iloc

# %% [markdown]
# **take**

# %%
visadataset_df.take([100,200,300],axis=0)  # selected rows all the columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
cols=[1,8,11]
visadataset_df.take(cols,axis=1)
# Out:
#       continent  prevailing_wage case_status
# 0          Asia         592.2029      Denied
# 1          Asia       83425.6500   Certified
# 2          Asia      122996.8600      Denied
# 3          Asia       83434.0300      Denied
# 4        Africa      149907.3900   Certified
# ...         ...              ...         ...
# 25475      Asia       77092.5700   Certified
# 25476      Asia      279174.7900   Certified
# 25477      Asia      146298.8500   Certified
# 25478      Asia       86154.7700   Certified
# 25479      Asia       70876.9100   Certified
#
# [25480 rows x 3 columns]

# %%
cols=[1,8,11]
rows=[100,200,300]
visadataset_df.take(cols,axis=1).take(rows,axis=0)
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
visadataset_df.take([2:5],axis=1)
# Out:
#   Cell In[9], line 1
#     visadataset_df.take([2:5],axis=1)
#                           ^
# SyntaxError: invalid syntax

# %%
l1=range(2,5)
visadataset_df.take(l1,axis=0)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %%
l1=range(2,5)
l2=[2,3,4,5]
l3=[2:5]
visadataset_df.take(l1,axis=0)
visadataset_df.take(l2,axis=0)
visadataset_df.take(l3,axis=0)
visadataset_df.take(5,axis=0)
# Out:
#   Cell In[11], line 3
#     l3=[2:5]
#          ^
# SyntaxError: invalid syntax

# %%
l1=range(2,5)
visadataset_df.take(l1,axis=0)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %%
l2=[2,3,4,5]
visadataset_df.take(l2,axis=0)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified
# ...

# %%
l3=[2:5]
visadataset_df.take(l3,axis=0)
# Out:
#   Cell In[166], line 1
#     l3=[2:5]
#          ^
# SyntaxError: invalid syntax

# %%
visadataset_df.take(5,axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 visadataset_df.take(5,axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:893, in BaseBlockManager.take(self, indexer, axis, verify)
#     890 n = self.shape[axis]
# ...

# %% [markdown]
# - drawback: at a time either we can select rows or columns

# %% [markdown]
# **iloc**

# %%
cols=[1,8,11]
rows=[100,200,300]
visadataset_df.iloc[rows,cols]
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
visadataset_df.iloc[[100,200,300],[1,8,11]]
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
visadataset_df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visadataset_df.iloc[[1,8,11]]
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 1   EZYV02      Asia              Master's                  Y
# 8   EZYV09      Asia            Bachelor's                  N
# 11  EZYV12      Asia           High School                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                      N             2412         2002            Northeast
# 8                      N             4810         2012              Midwest
# 11                     N             4069         2005            Northeast
#
#     prevailing_wage unit_of_wage full_time_position case_status
# 1          83425.65         Year                  Y   Certified
# 8          74362.19         Year                  Y   Certified
# 11         70813.09         Year                  Y      Denied

# %%
visadataset_df.iloc[[100:105],[1,8,11]]
# Out:
#   Cell In[27], line 1
#     visadataset_df.iloc[[100:105,[1,8,11]]
#                             ^
# SyntaxError: invalid syntax

# %%
visadataset_df.iloc[100:105],[1,8,11]
# Out:
# (     case_id continent education_of_employee has_job_experience  \
#  100  EZYV101      Asia              Master's                  Y
#  101  EZYV102      Asia              Master's                  Y
#  102  EZYV103      Asia            Bachelor's                  Y
#  103  EZYV104      Asia             Doctorate                  Y
#  104  EZYV105      Asia              Master's                  Y
#
#      requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
#  100                     N             2227         2007            Northeast
#  101                     N              334         2007              Midwest
#  102                     N              224         2008              Midwest
#  103                     N              367         1982                 West
#  104                     N              306         2003            Northeast
#
#       prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
visadataset_df.iloc[[100,200,300],[1:4]]
# Out:
#   Cell In[22], line 1
#     visadataset_df.iloc[[100,200,300],[1:4]]
#                                         ^
# SyntaxError: invalid syntax

# %%
visadataset_df.iloc[[100,200,300],1:4]
# Out:
#     continent education_of_employee has_job_experience
# 100      Asia              Master's                  Y
# 200      Asia             Doctorate                  Y
# 300      Asia              Master's                  Y

# %%
visadataset_df.iloc[range(1,5),range(1,3)]
# Out:
#   continent education_of_employee
# 1      Asia              Master's
# 2      Asia            Bachelor's
# 3      Asia            Bachelor's
# 4    Africa              Master's

# %%
visadataset_df.iloc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visadataset_df.iloc[[100,200,300],['continent']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 visadataset_df.iloc[[100,200,300],['continent']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# ...

# %%
visadataset_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visadataset_df.columns.tolist()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visadataset_df.columns.tolist().index('case_status')
# Out:
# 11

# %% [markdown]
# **loc**

# %%
visadataset_df.loc[[100,200,300],['continent','prevailing_wage','case_status']]
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
visadataset_df.loc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visadataset_df.loc[[1,8,11]]
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 1   EZYV02      Asia              Master's                  Y
# 8   EZYV09      Asia            Bachelor's                  N
# 11  EZYV12      Asia           High School                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                      N             2412         2002            Northeast
# 8                      N             4810         2012              Midwest
# 11                     N             4069         2005            Northeast
#
#     prevailing_wage unit_of_wage full_time_position case_status
# 1          83425.65         Year                  Y   Certified
# 8          74362.19         Year                  Y   Certified
# 11         70813.09         Year                  Y      Denied

# %%
visadataset_df.loc[100:105],['continent','prevailing_wage','case_status']
# Out:
# (     case_id      continent education_of_employee has_job_experience  \
#  100  EZYV101           Asia              Master's                  Y
#  101  EZYV102           Asia              Master's                  Y
#  102  EZYV103           Asia            Bachelor's                  Y
#  103  EZYV104           Asia             Doctorate                  Y
#  104  EZYV105           Asia              Master's                  Y
#  105  EZYV106  North America             Doctorate                  Y
#
#      requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
#  100                     N             2227         2007            Northeast
#  101                     N              334         2007              Midwest
#  102                     N              224         2008              Midwest
#  103                     N              367         1982                 West
#  104                     N              306         2003            Northeast
# ...

# %%
visadataset_df.loc[[100,200,300],1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 visadataset_df.loc[[100,200,300],1:4]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
visadataset_df.loc[range(1,5),range(1,3)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 visadataset_df.loc[range(1,5),range(1,3)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
visadataset_df.loc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visadataset_df.loc[[100,200,300],['continent']]
# Out:
#     continent
# 100      Asia
# 200      Asia
# 300      Asia

# %%
- visa_df.loc[row_index,column_names] # bcoz row index is number only (1,2,3,4,etc)

# %%
# so whats the diff between iloc and loc
# iloc = integer location : loc = label location
# uses of iloc = index number (1,2,3 etc)
# uses of loc = row , column names and label
# when to use iloc = when know position of row and column
# when to use loc = when know the name of row and column

# %% [markdown]
# #### 25/04/25

# %% [markdown]
# **How to select columns**

# %%
# always whenever you open the new notebook
# step-1: import the packages
# step-2: read the data

# %%
visadataset_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visadataset_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visadataset_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visadataset_df['continent','case_status'] # fail bcz of single square bracket
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('continent', 'case_status')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 visadataset_df['continent','case_status']
#
# ...

# %%
visadataset_df[['continent','case_status']]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %%
visadataset_df.loc['continent']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 visadataset_df.loc['continent']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
# ...

# %%
visadataset_df.loc[:,'continent']  # series
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visadataset_df.loc[:,['continent']] # dataframe
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]
